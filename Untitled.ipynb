# %%
import numpy as np 
import cv2
import matplotlib.pyplot as plt
from imutils.object_detection import non_max_suppression

# %%
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

imagePath = "../images/FudanPed00003.png"

img = cv2.imread(imagePath)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
print(img.shape)
# Out:
# (445, 479, 3)

# %%
def human_detection(img):
    if len(img.shape) != 3: 
        raise Exception("The image must have dimension of 3!")
    if img.shape[-1] != 3: 
        raise Exception("The image must be a RGB image!")
    
    (rects, weights) = hog.detectMultiScale(img, winStride=(20, 20), padding=(10, 10), scale=1.05)

    for (x, y, w, h) in rects:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 2)
        
    return img
    
    # rects = np.array([[x, y, x + w, y + h] for (x, y, w, h) in rects])
    # pick = non_max_suppression(rects, probs=None, overlapThresh=0.65)

    # for (xA, yA, xB, yB) in pick:
    #     cv2.rectangle(img, (xA, yA), (xB, yB), (0, 255, 0), 2)

# %%
image = human_detection(img)

# %%
plt.imshow(image)
print(image.shape)
# Out:
# (445, 479, 3)

# %%
cap = cv2.VideoCapture('../images/Walk1.mpg')

while(cap.isOpened()):
    ret, frame = cap.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
